# %%
import numpy as np
import matplotlib.pyplot as plt

#Fig. 1 - wpoływ pH na aktywność lipazy alkalicznej

strain_26_1B_rel_activity  = np.array([22, 40, 59, 64, 65, 71, 80, 97, 100, 90, 80])
strain_22_39B_rel_activity = np.array([24, 25, 26, 32, 35, 73, 79, 98, 100, 40, 24])
pH = np.array([3, 4, 5, 6, 7, 8, 8.5, 9, 9.5, 10, 10.5])

# %%
plt.plot(pH, strain_22_39B_rel_activity, 'ko-')

# %%
import numpy as np
import matplotlib.pyplot as plt

#Fig. 2 - wpoływ temperatury na aktywność lipazy alkalicznej


strain_26_1B_T = np.array([20, 30, 40, 45, 50, 55, 60, 65, 70, 80])
strain_26_1B_rel_activity  = np.array([23, 50, 80, 92, 100, 95, 90, 77, 40, 10])

strain_22_39B_T = np.array([20, 30, 40, 50, 60, 75, 80, 85, 90, 95, 98, 100])
strain_22_39B_rel_activity  = np.array([15, 25, 50, 78, 85, 95, 100, 100, 93, 60, 35, 10])
